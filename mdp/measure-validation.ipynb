# %%
import pickle
import seaborn as sns

# %%
with open("measure-validation.pkl", "rb") as pkl:
    load = pickle.load(pkl)
    fc16 = load["fc16"]
    aft20 = load["aft20"]
    our = load["our"]
    data = load["data"]

print("fc16", fc16["model"], fc16["mdp"], sep="\n")
print("aft20", aft20["model"], aft20["mdp"], sep="\n")
print()
print("our:", our["model"], our["mdp"], sep="\n")
data = data.assign(rpp_minus_alpha=data.rpp - data.alpha)
data
# Out:
# fc16
# fc16sapirshtein.BitcoinSM(alpha=0.125, gamma=0.25, maximum_fork_length=5)
# MDP of size 61 / 4 / 314 / 5.1
# aft20
# aft20barzur.BitcoinSM(alpha=0.125, gamma=0.25, maximum_fork_length=5)
# MDP of size 74 / 4 / 258 / 3.5
#
# our:
# sm.SelfishMining(Bitcoin(), alpha=0.125, gamma=0.25, maximum_height=5, maximum_size=0, force_consider_own=True)
# MDP of size 2502 / 4 / 11170 / 4.5
#      alpha  gamma  horizon   eps  model  vi_discount  vi_delta  vi_stop_delta
# 0     0.10   0.50      100  0.01   fc16            1  0.009930           0.01  \
# 1     0.10   0.50      100  0.01  aft20            1  0.009942           0.01
# 2     0.10   0.50      100  0.01    our            1  0.009910           0.01
# 3     0.10   0.25       25  0.01   fc16            1  0.009840           0.01
# 4     0.10   0.25       25  0.01  aft20            1  0.009872           0.01
# ..     ...    ...      ...   ...    ...          ...       ...            ...
# 400   0.35   0.25      100  0.01  aft20            1  0.009953           0.01
# 401   0.35   0.25      100  0.01    our            1  0.009993           0.01
# 402   0.10   0.50       50  0.01   fc16            1  0.009834           0.01
# 403   0.10   0.50       50  0.01  aft20            1  0.009881           0.01
# 404   0.10   0.50       50  0.01    our            1  0.009995           0.01
#
#      vi_iter  vi_max_iter  ...  vi_max_value  ss_reachable  ss_nonzero
# 0        231            0  ...     13.782607            15          15  \
# 1        439            0  ...     13.680209            17          17
# 2        462            0  ...     13.772553            45          45
# 3         58            0  ...      6.884462            15          15
# 4        111            0  ...      6.875378            17          17
# ..       ...          ...  ...           ...           ...         ...
# 400      601            0  ...     39.956938            35          35
# 401      654            0  ...     40.037515           129         129
# 402      116            0  ...      9.235089            15          15
# 403      221            0  ...      9.195794            17          17
# 404      230            0  ...      9.216713            45          45
#
#       ss_time  pe_iter     ptrev       rpp      time  vi_steady_value
# 0    0.054312        2  0.100000  0.100000  0.134112         9.018862  \
# 1    0.001792        2  0.050000  0.100000  0.202647         8.899200
# 2    0.001647        2  0.050000  0.100000  3.843170         9.018862
# 3    0.038846        2  0.100000  0.100000  0.055947         2.265754
# 4    0.001078        2  0.050000  0.100000  0.028185         2.240891
# ..        ...      ...       ...       ...       ...              ...
# 400  0.001290        2  0.181242  0.376718  0.145869        36.015615
# 401  0.001923        2  0.159342  0.381043  4.215524        36.195274
# 402  0.001067        2  0.100000  0.100000  0.034875         4.520051
# 403  0.001096        2  0.050000  0.100000  0.057993         4.464096
# 404  0.001239        2  0.050000  0.100000  1.898680         4.510256
#
#      rpp_minus_alpha
# 0      -1.096345e-15
# 1      -1.540434e-15
# 2      -8.340550e-15
# 3      -1.096345e-15
# 4      -1.540434e-15
# ..               ...
# 400     2.671792e-02
# 401     3.104314e-02
# 402    -1.096345e-15
# 403    -1.540434e-15
# 404     6.203371e-14
#
# [405 rows x 21 columns]

# %%
data[(data.ss_reachable - data.ss_nonzero) != 0]
# Out:
#      alpha  gamma  horizon   eps  model  vi_discount  vi_delta  vi_stop_delta
# 51    0.05   0.00       25  0.01   fc16            1  0.009808           0.01  \
# 52    0.05   0.00       25  0.01  aft20            1  0.009612           0.01
# 147   0.05   0.50       25  0.01   fc16            1  0.009808           0.01
# 148   0.05   0.50       25  0.01  aft20            1  0.009612           0.01
# 219   0.05   0.75       25  0.01   fc16            1  0.009808           0.01
# 220   0.05   0.75       25  0.01  aft20            1  0.009612           0.01
# 360   0.05   0.25       25  0.01   fc16            1  0.009808           0.01
# 361   0.05   0.25       25  0.01  aft20            1  0.009612           0.01
#
#      vi_iter  vi_max_iter  ...  vi_max_value  ss_reachable  ss_nonzero
# 51        41            0  ...      5.820096             4           3  \
# 52        81            0  ...      5.820096             5           4
# 147       41            0  ...      5.820096             4           3
# 148       81            0  ...      5.820096             5           4
# 219       41            0  ...      5.820096             4           3
# 220       81            0  ...      5.820096             5           4
# 360       41            0  ...      5.820096             4           3
# 361       81            0  ...      5.820096             5           4
#
#       ss_time  pe_iter  ptrev   rpp      time  vi_steady_value
# 51   0.001034        2  0.050  0.05  0.015803         1.015561  \
# 52   0.000949        2  0.025  0.05  0.022031         1.010755
# 147  0.000999        2  0.050  0.05  0.014428         1.015561
# 148  0.000851        2  0.025  0.05  0.021124         1.010755
# 219  0.000987        2  0.050  0.05  0.014220         1.015561
# 220  0.000891        2  0.025  0.05  0.020904         1.010755
# 360  0.000996        2  0.050  0.05  0.014532         1.015561
# 361  0.000913        2  0.025  0.05  0.021676         1.010755
#
#      rpp_minus_alpha
# 51     -2.359224e-16
# 52     -6.106227e-16
# 147    -2.359224e-16
# 148    -6.106227e-16
# 219    -2.359224e-16
# 220    -6.106227e-16
# 360    -2.359224e-16
# 361    -6.106227e-16
#
# [8 rows x 21 columns]

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="vi_steady_value",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="ptrev",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="model",
    style="gamma",
    hue="gamma",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Demonstrate effect of horizon
sns.relplot(
    data.query("eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    hue="model",
    style="horizon",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Demonstrate effect of eps
sns.relplot(
    data.query("horizon==horizon.max()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    hue="model",
    style="eps",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Visualize number iterations required in value iteration
# It's intersting that the models behave so similar!
sns.relplot(
    data,
    x="alpha",
    y="vi_iter",
    col="gamma",
    hue="model",
    row="eps",
    style="horizon",
    kind="line",
    markers=True,
)

# %%
# Visualize solving time
# Naturally, the smaller model can be iterated much faster
sns.relplot(
    data,
    x="vi_iter",
    y="vi_time",
    hue="horizon",
    style="eps",
    col="model",
    facet_kws=dict(sharey=False),
)

# %%
# Size of policy / steady state
sns.relplot(
    data,
    x="alpha",
    y="ss_nonzero",
    col="gamma",
    row="horizon",
    hue="model",
    kind="line",
    markers=True,
)

# %%
# We're now interested in the difference between the models
# Can we bring the difference down by selecting better hyper params?
diff = data.pivot(
    index=["alpha", "gamma", "horizon", "eps"], columns="model", values=["rpp"]
)
diff.columns = [j for i, j in diff.columns]
diff["diff"] = diff.fc16 - diff.our
diff = diff.reset_index()
sns.relplot(
    kind="line",
    data=diff,
    x="alpha",
    y="diff",
    row="horizon",
    col="gamma",
    hue="eps",
).refline(y=0)
