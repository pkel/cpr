# %%
import pickle
import seaborn as sns

# %%
with open("measure-validation.pkl", "rb") as pkl:
    load = pickle.load(pkl)
    fc16 = load["fc16"]
    aft20 = load["aft20"]
    our = load["our"]
    data = load["data"]

print("fc16", fc16["model"], fc16["mdp"], sep="\n")
print("aft20", aft20["model"], aft20["mdp"], sep="\n")
print()
print("our:", our["model"], our["mdp"], sep="\n")
data = data.assign(rpp_minus_alpha=data.rpp - data.alpha)
data
# Out:
# fc16
# fc16sapirshtein.BitcoinSM(alpha=0.125, gamma=0.25, maximum_fork_length=13)
# MDP of size 417 / 4 / 2362 / 5.7
# aft20
# aft20barzur.BitcoinSM(alpha=0.125, gamma=0.25, maximum_fork_length=13)
# MDP of size 454 / 4 / 1722 / 3.8
#
# our:
# sm.SelfishMining(Bitcoin(), alpha=0.125, gamma=0.25, maximum_height=13, maximum_size=0, force_consider_own=True)
# MDP of size 159819 / 4 / 846080 / 5.3
#      alpha  gamma  horizon   eps  model  vi_discount  vi_delta  vi_stop_delta
# 0     0.25   0.50       25  0.01   fc16            1  0.009711           0.01  \
# 1     0.25   0.50       25  0.01  aft20            1  0.009872           0.01
# 2     0.25   0.50       25  0.01    our            1  0.009583           0.01
# 3     0.45   1.00       50  0.01   fc16            1  0.009952           0.01
# 4     0.45   1.00       50  0.01  aft20            1  0.009922           0.01
# ..     ...    ...      ...   ...    ...          ...       ...            ...
# 400   0.40   0.75       50  0.01  aft20            1  0.009948           0.01
# 401   0.40   0.75       50  0.01    our            1  0.009930           0.01
# 402   0.30   0.75      100  0.01   fc16            1  0.009932           0.01
# 403   0.30   0.75      100  0.01  aft20            1  0.009963           0.01
# 404   0.30   0.75      100  0.01    our            1  0.009961           0.01
#
#      vi_iter  vi_max_iter  ...  vi_max_value  ss_reachable  ss_nonzero
# 0         84            0  ...     17.211788           142         142  \
# 1        128            0  ...     17.063486           142         142
# 2        147            0  ...     17.244469           829         829
# 3        333            0  ...     45.417903           237         237
# 4        396            0  ...     45.250913           263         263
# ..       ...          ...  ...           ...           ...         ...
# 400      352            0  ...     37.109433           235         235
# 401      423            0  ...     38.898893          3481        3481
# 402      464            0  ...     48.232718           249         249
# 403      603            0  ...     45.366565           196         196
# 404      674            0  ...     47.337924          2469        2469
#
#       ss_time  pe_iter     ptrev       rpp        time  vi_steady_value
# 0    0.030933        2  0.204995  0.249974    0.154395         6.425462  \
# 1    0.002084        2  0.116836  0.249975    0.137341         6.036471
# 2    0.063768        2  0.108854  0.249904   67.625856         6.235046
# 3    0.032954        2  0.450000  0.788426    0.491456        41.554181
# 4    0.004900        2  0.357169  0.787252    0.405291        40.984734
# ..        ...      ...       ...       ...         ...              ...
# 400  0.003853        2  0.254737  0.549392    0.368678        28.194043
# 401  2.454811        2  0.229374  0.618313  184.720154        31.252732
# 402  0.004395        2  0.265724  0.379090    0.641664        37.225727
# 403  0.002980        2  0.163203  0.352231    0.627965        33.671015
# 404  0.909433        2  0.153466  0.379184  287.169326        35.942575
#
#      rpp_minus_alpha
# 0          -0.000026
# 1          -0.000025
# 2          -0.000096
# 3           0.338426
# 4           0.337252
# ..               ...
# 400         0.149392
# 401         0.218313
# 402         0.079090
# 403         0.052231
# 404         0.079184
#
# [405 rows x 21 columns]

# %%
data[(data.ss_reachable - data.ss_nonzero) != 0]
# Out:
#      alpha  gamma  horizon   eps  model  vi_discount  vi_delta  vi_stop_delta
# 15    0.05   0.50       50  0.01   fc16            1  0.009829           0.01  \
# 16    0.05   0.50       50  0.01  aft20            1  0.009811           0.01
# 67    0.15   0.75       25  0.01  aft20            1  0.009857           0.01
# 72    0.05   0.75       50  0.01   fc16            1  0.009829           0.01
# 73    0.05   0.75       50  0.01  aft20            1  0.009811           0.01
# 87    0.05   0.25       25  0.01   fc16            1  0.009964           0.01
# 88    0.05   0.25       25  0.01  aft20            1  0.009612           0.01
# 111   0.05   0.00       25  0.01   fc16            1  0.009964           0.01
# 112   0.05   0.00       25  0.01  aft20            1  0.009612           0.01
# 117   0.10   0.50       25  0.01   fc16            1  0.009759           0.01
# 123   0.05   0.25       50  0.01   fc16            1  0.009829           0.01
# 124   0.05   0.25       50  0.01  aft20            1  0.009811           0.01
# 144   0.10   0.00       25  0.01   fc16            1  0.009759           0.01
# 162   0.10   0.25       25  0.01   fc16            1  0.009759           0.01
# 196   0.15   0.25       25  0.01  aft20            1  0.009857           0.01
# 208   0.15   0.50       25  0.01  aft20            1  0.009857           0.01
# 234   0.05   0.00       50  0.01   fc16            1  0.009829           0.01
# 235   0.05   0.00       50  0.01  aft20            1  0.009811           0.01
# 236   0.05   0.00       50  0.01    our            1  0.009932           0.01
# 241   0.15   0.00       25  0.01  aft20            1  0.009857           0.01
# 300   0.10   0.75       25  0.01   fc16            1  0.009760           0.01
# 327   0.05   0.75       25  0.01   fc16            1  0.009964           0.01
# 328   0.05   0.75       25  0.01  aft20            1  0.009612           0.01
# 387   0.05   0.50       25  0.01   fc16            1  0.009964           0.01
# 388   0.05   0.50       25  0.01  aft20            1  0.009612           0.01
#
#      vi_iter  vi_max_iter  ...  vi_max_value  ss_reachable  ss_nonzero
# 15        82            0  ...     14.548281             4           3  \
# 16       159            0  ...     14.532848             5           4
# 67       127            0  ...     15.037238             5           4
# 72        82            0  ...     14.548281             4           3
# 73       159            0  ...     14.532848             5           4
# 87        41            0  ...     13.591608             4           3
# 88        81            0  ...     13.591608             5           4
# 111       41            0  ...     13.591608             4           3
# 112       81            0  ...     13.591608             5           4
# 117       59            0  ...     14.332720             4           3
# 123       82            0  ...     14.548281             4           3
# 124      159            0  ...     14.532848             5           4
# 144       59            0  ...     14.332720             4           3
# 162       59            0  ...     14.332720             4           3
# 196      127            0  ...     15.037238             5           4
# 208      127            0  ...     15.037238             5           4
# 234       82            0  ...     14.548281             4           3
# 235      159            0  ...     14.532848             5           4
# 236      162            0  ...     14.620646           176         175
# 241      127            0  ...     15.037238             5           4
# 300       59            0  ...     14.332720             4           3
# 327       41            0  ...     13.591608             4           3
# 328       81            0  ...     13.591608             5           4
# 387       41            0  ...     13.591608             4           3
# 388       81            0  ...     13.591608             5           4
#
#       ss_time  pe_iter  ptrev   rpp       time  vi_steady_value
# 15   0.029790        2  0.050  0.05   0.148920         2.023044  \
# 16   0.000891        2  0.025  0.05   0.169144         1.998473
# 67   0.001263        2  0.075  0.15   0.262531         3.470035
# 72   0.000822        2  0.050  0.05   0.121033         2.023044
# 73   0.000802        2  0.025  0.05   0.166529         1.998473
# 87   0.000871        2  0.050  0.05   0.065160         1.015561
# 88   0.000784        2  0.025  0.05   0.087541         1.010755
# 111  0.000800        2  0.050  0.05   0.065916         1.015561
# 112  0.000896        2  0.025  0.05   0.087626         1.010755
# 117  0.000852        2  0.100  0.10   0.089438         2.275124
# 123  0.000777        2  0.050  0.05   0.126824         2.023044
# 124  0.000788        2  0.025  0.05   0.164763         1.998473
# 144  0.001302        2  0.100  0.10   0.175515         2.275124
# 162  0.000801        2  0.100  0.10   0.089244         2.275124
# 196  0.000793        2  0.075  0.15   0.133628         3.470035
# 208  0.000775        2  0.075  0.15   0.134393         3.470035
# 234  0.000806        2  0.050  0.05   0.136332         2.023044
# 235  0.000801        2  0.025  0.05   0.164385         1.998473
# 236  0.003003        2  0.025  0.05  72.912262         2.013310
# 241  0.000795        2  0.075  0.15   0.135218         3.470035
# 300  0.000766        2  0.100  0.10   0.088306         2.275124
# 327  0.000764        2  0.050  0.05   0.064120         1.015561
# 328  0.000731        2  0.025  0.05   0.087373         1.010755
# 387  0.000813        2  0.050  0.05   0.070478         1.015561
# 388  0.000764        2  0.025  0.05   0.093581         1.010755
#
#      rpp_minus_alpha
# 15     -2.359224e-16
# 16     -6.106227e-16
# 67      1.387779e-16
# 72     -2.359224e-16
# 73     -6.106227e-16
# 87     -2.359224e-16
# 88     -6.106227e-16
# 111    -2.359224e-16
# 112    -6.106227e-16
# 117    -1.249001e-16
# 123    -2.359224e-16
# 124    -6.106227e-16
# 144    -1.249001e-16
# 162    -1.249001e-16
# 196     1.387779e-16
# 208     1.387779e-16
# 234    -2.359224e-16
# 235    -6.106227e-16
# 236    -1.456474e-14
# 241     1.387779e-16
# 300    -1.249001e-16
# 327    -2.359224e-16
# 328    -6.106227e-16
# 387    -2.359224e-16
# 388    -6.106227e-16
#
# [25 rows x 21 columns]

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="vi_steady_value",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="ptrev",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    style="horizon",
    hue="model",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Compare model w.r.t. reward
sns.relplot(
    data.query("horizon==horizon.max() and eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="model",
    style="gamma",
    hue="gamma",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Demonstrate effect of horizon
sns.relplot(
    data.query("eps==eps.min()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    hue="model",
    style="horizon",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Demonstrate effect of eps
sns.relplot(
    data.query("horizon==horizon.max()"),
    x="alpha",
    y="rpp_minus_alpha",
    col="gamma",
    hue="model",
    style="eps",
    kind="line",
    markers=True,
).refline(y=0)

# %%
# Visualize number iterations required in value iteration
# It's intersting that the models behave so similar!
sns.relplot(
    data,
    x="alpha",
    y="vi_iter",
    col="gamma",
    hue="model",
    row="eps",
    style="horizon",
    kind="line",
    markers=True,
)

# %%
# Visualize solving time
# Naturally, the smaller model can be iterated much faster
sns.relplot(
    data,
    x="vi_iter",
    y="vi_time",
    hue="horizon",
    style="eps",
    col="model",
    facet_kws=dict(sharey=False),
)

# %%
# Size of policy / steady state
sns.relplot(
    data,
    x="alpha",
    y="ss_nonzero",
    col="gamma",
    row="horizon",
    hue="model",
    kind="line",
    markers=True,
)

# %%
# We're now interested in the difference between the models
# Can we bring the difference down by selecting better hyper params?
diff = data.pivot(
    index=["alpha", "gamma", "horizon", "eps"], columns="model", values=["rpp"]
)
diff.columns = [j for i, j in diff.columns]
diff["diff"] = diff.fc16 - diff.our
diff = diff.reset_index()
sns.relplot(
    kind="line",
    data=diff,
    x="alpha",
    y="diff",
    row="horizon",
    col="gamma",
    hue="eps",
).refline(y=0)
