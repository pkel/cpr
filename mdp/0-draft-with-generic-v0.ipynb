# %%
from lib.models.generic_v0.bitcoin import Bitcoin
from lib.models.generic_v0 import model as sm
from lib import explicit_mdp as mdp
from lib import implicit_mdp as model

# %%
protocol = Bitcoin()
alpha = 0.25
gamma = 0.25

# implicit SM model
# careful: this truncates the common chain; that mechanism is easy to define for Bitcoin but might cause headaches for other protocols
# take in mind that the (absence of) truncation might affect the rest of the algorithm
base_model = sm.SelfishMining(protocol, alpha=alpha, gamma=gamma, maximum_size=1000000)

terminal_state = b""
horizon = 100

# implicit SM model with PTO applied on the fly
pto_model = model.PTO_wrapper(
    base_model, horizon=horizon, terminal_state=terminal_state
)

# %% [markdown]
# # Level 0: explore honest policy, derive MC, evaluate
#
# #### L0.1: explore states and build MC

# %%
# This will probably not terminate when we remove truncation!
def explore_policy(m, policy):
    states = dict()
    queue = set()

    for s, p in m.start():
        queue.add(s)

    while len(queue) > 0:
        s = queue.pop()

        assert s not in states
        states[s] = []

        a = policy(s)
        for t in m.apply(a, s):
            if t.probability == 0:
                continue

            states[s].append((t.state, t.probability, t.reward, t.progress))

            if t.state in states or t.state == terminal_state:
                continue
            else:
                queue.add(t.state)

    states[terminal_state] = []  # no transitions available in terminal_state

    return m.start(), states


def explore_honest(m):
    return explore_policy(m, m.honest)


def with_int_states(mc):
    start, tx = mc
    table = {s: i for i, s in enumerate(tx.keys())}
    istart = []
    for s0, p in start:
        istart.append((table[s0], p))
    istart = sorted(istart)
    itx = []
    for s0, tx_lst in tx.items():
        itx.append([(table[s1], prb, rew, prg) for s1, prb, rew, prg in tx_lst])
    return istart, itx


mc = explore_honest(base_model)
with_int_states(mc)
# Out:
# ([(0, 0.75), (1, 0.25)],
#  [[(6, 0.0625, 0.0, 0),
#    (3, 0.1875, 0.0, 0),
#    (6, 0.1875, 0.0, 0),
#    (3, 0.5625, 0.0, 0)],
#   [(5, 0.0625, 0.0, 0),
#    (2, 0.1875, 0.0, 0),
#    (5, 0.1875, 0.0, 0),
#    (2, 0.5625, 0.0, 0)],
#   [(8, 1, 0.0, 0)],
#   [(4, 1, 0.0, 0)],
#   [(6, 0.0625, 0.0, 1),
#    (3, 0.1875, 0.0, 1),
#    (6, 0.1875, 0.0, 1),
#    (3, 0.5625, 0.0, 1)],
#   [(9, 1, 0.0, 0)],
#   [(7, 1, 0.0, 0)],
#   [(5, 0.0625, 1.0, 1),
#    (2, 0.1875, 1.0, 1),
#    (5, 0.1875, 1.0, 1),
#    (2, 0.5625, 1.0, 1)],
#   [(6, 0.0625, 0.0, 1),
#    (3, 0.1875, 0.0, 1),
#    (6, 0.1875, 0.0, 1),
#    (3, 0.5625, 0.0, 1)],
#   [(5, 0.0625, 1.0, 1),
#    (2, 0.1875, 1.0, 1),
#    (5, 0.1875, 1.0, 1),
#    (2, 0.5625, 1.0, 1)],
#   []])

# %% [markdown]
# #### L0.2: evaluate MC; RTDP style
#
# - random walk through the MC
# - back-propagate values
#
# This should converge quickly initially as is focuses on important states.
# For the same reason it will slow down when getting closer to the true limits.

# %%
import random


def sample_next_state_and_map(tx_lst, fun):
    x = random.random()
    i = None
    acc_prb = 0.0
    ret = []
    for j, tx in enumerate(tx_lst):
        ret.append(fun(tx))
        if acc_prb <= x:
            i = j
        acc_prb += tx[1]
    next_state = tx_lst[i][0]
    return next_state, ret


def mc_path_backpropagation_eval(m, policy):
    start, tx = with_int_states(explore_policy(m, policy))

    count = [0] * len(tx)
    value = [0.0] * len(tx)
    prg_v = [0.0] * len(tx)
    state, _ = sample_next_state_and_map(start, lambda x: None)
    terminating = False

    n_steps = 100000
    for i in range(n_steps):
        if len(tx[state]) < 1:  # terminal state
            terminating = True
            state, _ = sample_next_state_and_map(start, lambda x: None)

        def fun(t):
            next_state, prb, rew, prg = t
            return prb * (rew + value[next_state]), prb * (prg + prg_v[next_state])

        next_state, values_and_prg_vs = sample_next_state_and_map(tx[state], fun)
        values, prg_vs = zip(*values_and_prg_vs)
        value[state] = sum(values)
        prg_v[state] = sum(prg_vs)
        count[next_state] += 1
        state = next_state

    # start state estimate
    start_value_estimate = sum([value[s] * p for s, p in start])
    start_prg_v_estimate = sum([prg_v[s] * p for s, p in start])

    if terminating:
        return start_value_estimate, start_prg_v_estimate, value, prg_v

    else:
        # steady state estimate
        # note: steady state don't make sense for PTO; the terminal state is the steady state!
        assert sum(count) == n_steps
        steady_state = [c / n_steps for c in count]
        steady_state_value = sum([v * c for v, c in zip(value, count)]) / n_steps
        steady_state_prg_v = sum([v * c for v, c in zip(prg_v, count)]) / n_steps

        return (
            start_value_estimate,
            start_prg_v_estimate,
            value,
            prg_v,
            steady_state,
            steady_state_value,
            steady_state_prg_v,
        )

# %%
expected_reward, expected_progress, _, _ = mc_path_backpropagation_eval(
    pto_model, pto_model.honest
)
assert abs(expected_progress - horizon) < 0.00001
expected_reward / expected_progress, alpha
# Out:
# (0.24999999999999736, 0.25)

# %%
_, _, _, _, _, expected_reward, expected_progress = mc_path_backpropagation_eval(
    base_model, base_model.honest
)
expected_reward / expected_progress, alpha
# Out:
# (0.25002038480389555, 0.25)

# %% [markdown]
# # Level 1: explore MDP around honest policy

# %%
# This will probably not terminate when we remove common chain truncation in the selfish mining model!


def explore_around_policy(m, policy, max_distance=0):
    states = (
        dict()
    )  # state -> action -> list of transitions (next state, probability, reward, progress, ...)
    queue = set()  # states to be explored
    distances = dict()  # state -> distance to honest policy

    def distance(s):
        return distances.get(s, float("inf"))

    for s, p in m.start():
        queue.add(s)
        distances[s] = 0

    while len(queue) > 0:
        s = queue.pop()
        d = distances[s]

        assert s not in states
        states[s] = dict()

        h = policy(s)
        for a in m.actions(s):
            states[s][a] = []
            for t in m.apply(a, s):
                if t.probability == 0:
                    continue

                states[s][a].append(t)

                if a == h:
                    distances[t.state] = min(distance(t.state), distances[s])
                else:
                    distances[t.state] = min(distance(t.state), distances[s] + 1)
                # I'm not sure about this mechanism
                # What if we find a new path to a state with smaller distance than known before?
                # What's the distance of state that can be reached with honest policy but only from a state with disctance > 0?
                # I guess the right approach is incremental exploration: explore distance = 0; then = 1, and so on.
                #
                # Edit: This approach is certainly wrong. The resulting mdp size is not deterministic! It's fixed in the
                # Explorer class below.

                if distances[t.state] > max_distance:
                    continue

                if t.state in states or t.state == terminal_state:
                    continue
                else:
                    queue.add(t.state)

    states[terminal_state] = []  # no transitions available in terminal_state

    return m.start(), states


start, m = explore_around_policy(pto_model, pto_model.honest, max_distance=3)
len(m)
# Out:
# 205

# %%
# implementing the above loop as incremental exploration

from copy import deepcopy


# Invariant:
# - policy-defined actions are explored first
# - in the result MDP: policy = lambda s: 0
# - states are enumerated in order of exploration
# - states far off the policy have higher state ids than state closer or on the policy
# - policies for smaller MDPs are compatible with policies for bigger MDPs
class Explorer:
    def __init__(self, model, policy):
        self.model = model
        self.policy = policy

        self._mdp = mdp.MDP()
        self.states = []  # state id int -> state
        self.policy_tab = []  # state id int -> action

        self._state_id = dict()  # state -> state id int; see self.state_id()
        self.explored_upto = -1  # state id int; policy action has been explored
        self.fully_explored_upto = -1  # state id int; all actions have been explored

        for s, p in self.model.start():
            self._mdp.start[self.state_id(s)] = p

    def state_id(self, state):
        if state in self._state_id:
            return self._state_id[state]
        else:
            i = len(self._state_id)
            self._state_id[state] = i
            self.states.append(state)
            return i

    @property
    def n_states(self):
        return len(self._state_id)

    @property
    def max_state_id(self):
        return len(self._state_id) - 1

    def explore_along_policy(self):
        while self.max_state_id > self.explored_upto:
            self.explored_upto += 1
            s_id = self.explored_upto
            s = self.states[s_id]

            assert (
                len(self.policy_tab) == s_id
            ), f"logic error, {len(self.policy_tab)} == {s_id}"

            if len(self.model.actions(s)) == 0:
                # s is a terminal state
                self.policy_tab.append(-1)  # policy is not defined, put placeholder
                continue

            a = self.policy(s)
            self.policy_tab.append(a)

            for t in self.model.apply(a, s):
                if t.probability == 0:
                    continue

                t = mdp.Transition(
                    probability=t.probability,
                    destination=self.state_id(t.state),
                    reward=t.reward,
                    progress=t.progress,
                    effect=t.effect,
                )
                self._mdp.add_transition(src=s_id, act=0, t=t)

            self.explored_upto = s_id

    def explore_aside_policy(self):
        self.explore_along_policy()
        assert self.explored_upto == self.max_state_id

        while self.fully_explored_upto < self.explored_upto:
            self.fully_explored_upto += 1
            s_id = self.fully_explored_upto
            s = self.states[s_id]

            a_idx = 0  # policy action has a_idx = 0
            for a in self.model.actions(s):
                if a == self.policy_tab[s_id]:
                    # policy action; already explored
                    continue

                a_idx += 1

                for t in self.model.apply(a, s):
                    if t.probability == 0:
                        continue

                    t = mdp.Transition(
                        probability=t.probability,
                        destination=self.state_id(t.state),
                        reward=t.reward,
                        progress=t.progress,
                        effect=t.effect,
                    )
                    self._mdp.add_transition(src=s_id, act=a_idx, t=t)

    def mdp(self):
        # Note 1. For some states in self.partial_mdp; we've only explored the honest action.
        # That's okay, it forces the attacker to abort the attack.
        # Note 2. Some states are reachable but not yet explored; we have to fix this before
        # returning the MDP.
        self.explore_along_policy()
        assert self.explored_upto == self.max_state_id

        self._mdp.check()

        return deepcopy(self._mdp)


e = Explorer(pto_model, pto_model.honest)
d = 0
m = e.mdp()
ms = [m]
n = m.n_states
print(d, n)
for i in range(5):
    e.explore_aside_policy()
    d += 1
    m = e.mdp()
    ms.append(m)
    prev_n = n
    n = m.n_states
    print(d, n, n / prev_n)
# Out:
# 0 11
# 1 37 3.3636363636363638
# 2 111 3.0
# 3 279 2.5135135135135136
# 4 601 2.154121863799283
# 5 1166 1.940099833610649

# %% [markdown]
# # Level 2: optimize the MDPs

# %%
def evaluate(m, m_honest):
    res = m.value_iteration(stop_delta=0.00001)
    res["episode_reward"] = sum(res["vi_value"][s] * p for s, p in m.start.items())
    res["episode_progress"] = sum(res["vi_progress"][s] * p for s, p in m.start.items())
    res["reward_per_progress"] = res["episode_reward"] / res["episode_progress"]

    res["fully_honest"] = all(a < 1 for a in res["vi_policy"])
    # It at first came unexpeted to me, that vi_policy has dishonest entries while the honest policy was optimal.
    # Turns out the dishonest behavior happens on states that cannot be reached from the honest policy.
    # I'm now comparing the policies for only these states which can be rewach from the honest policy.
    # If the agent acts honest on these states it acts honest everywhere.
    res["honest"] = all(a < 1 for a in res["vi_policy"][: m_honest.n_states])
    return res


for d, m in enumerate(ms):
    res = evaluate(m, ms[0])
    print(
        d,
        m.n_states,
        res["fully_honest"],
        res["honest"],
        res["episode_progress"],
        res["reward_per_progress"],
    )
# Out:
# 0 11 True True 99.99601639605103 0.2499999999999963
# 1 37 True True 99.99605623209052 0.2499999999999963
# 2 111 False True 99.99609566976963 0.2499999999999963
# 3 279 False True 99.99609566976963 0.2499999999999963
# 4 601 False True 99.99613471307195 0.24999999999999628
# 5 1166 False True 99.99613471307195 0.24999999999999628

# %% [markdown]
# # Level 3: Find break-even points

# %%
evaluations = dict()
break_even = dict()

# %%
gamma = 0.0
distance = 5
precision = 12


def localize_be(gamma, distance, precision, protocol=protocol):
    upper_alpha = 1
    lower_alpha = 0
    for i in range(precision):
        alpha = (upper_alpha + lower_alpha) / 2
        base_model = sm.SelfishMining(
            protocol, alpha=alpha, gamma=gamma, maximum_size=1000000
        )
        pto_model = model.PTO_wrapper(
            base_model, horizon=horizon, terminal_state=terminal_state
        )

        attack_found = False
        e = Explorer(pto_model, pto_model.honest)
        m_honest = e.mdp()
        for d in range(1, distance + 1):
            e.explore_aside_policy()  # increase distance by one
            m = e.mdp()

        res = evaluate(m, m_honest)
        evaluations[(gamma, distance, alpha)] = res
        # if res["honest"]:
        if res["reward_per_progress"] <= alpha:
            print(f"no attack for alpha={alpha}")
        else:
            rpp = res["reward_per_progress"]
            print(f"   attack for alpha={alpha} w/ rpp={rpp}")
            attack_found = True

        if attack_found:
            upper_alpha = alpha
        else:
            lower_alpha = alpha

    break_even[(gamma, distance)] = upper_alpha

# %%
for gamma in [0, 0.25, 0.5, 0.75, 1]:
    for distance in range(1, 6):
        print(f"gamma = {gamma}, distance = {distance}")
        localize_be(gamma, distance, precision)
# Out:
# gamma = 0, distance = 1
#    attack for alpha=0.5 w/ rpp=0.5000000000000019
#    attack for alpha=0.25 w/ rpp=0.25000000000000205
# no attack for alpha=0.125
# no attack for alpha=0.1875
# no attack for alpha=0.21875
#    attack for alpha=0.234375 w/ rpp=0.23437500000000047
# no attack for alpha=0.2265625
# no attack for alpha=0.23046875
# no attack for alpha=0.232421875
# no attack for alpha=0.2333984375
#    attack for alpha=0.23388671875 w/ rpp=0.2338867187500001
# no attack for alpha=0.233642578125
# gamma = 0, distance = 2
#    attack for alpha=0.5 w/ rpp=0.5526505013144368
#    attack for alpha=0.25 w/ rpp=0.25000000000000205
# no attack for alpha=0.125
# no attack for alpha=0.1875
# no attack for alpha=0.21875
#    attack for alpha=0.234375 w/ rpp=0.23437500000000044
# no attack for alpha=0.2265625
# no attack for alpha=0.23046875
# no attack for alpha=0.232421875
# no attack for alpha=0.2333984375
#    attack for alpha=0.23388671875 w/ rpp=0.23388671875000008
# no attack for alpha=0.233642578125
# gamma = 0, distance = 3
#    attack for alpha=0.5 w/ rpp=0.5886791048892639
#    attack for alpha=0.25 w/ rpp=0.25000000000000205
# no attack for alpha=0.125
# no attack for alpha=0.1875
# no attack for alpha=0.21875
#    attack for alpha=0.234375 w/ rpp=0.23437500000000044
# no attack for alpha=0.2265625
# no attack for alpha=0.23046875
# no attack for alpha=0.232421875
# no attack for alpha=0.2333984375
#    attack for alpha=0.23388671875 w/ rpp=0.23388671875000008
# no attack for alpha=0.233642578125
# gamma = 0, distance = 4
#    attack for alpha=0.5 w/ rpp=0.6046076049951569
#    attack for alpha=0.25 w/ rpp=0.25000000000000205
# no attack for alpha=0.125
# no attack for alpha=0.1875
# no attack for alpha=0.21875
#    attack for alpha=0.234375 w/ rpp=0.23437500000000044
# no attack for alpha=0.2265625
# no attack for alpha=0.23046875
#    attack for alpha=0.232421875 w/ rpp=0.23242187500000003
#    attack for alpha=0.2314453125 w/ rpp=0.23144531250000092
# no attack for alpha=0.23095703125
#    attack for alpha=0.231201171875 w/ rpp=0.2312011718750009
# gamma = 0, distance = 5
#    attack for alpha=0.5 w/ rpp=0.6401050806207231
#    attack for alpha=0.25 w/ rpp=0.25000000000000205
# no attack for alpha=0.125
# no attack for alpha=0.1875
# no attack for alpha=0.21875
#    attack for alpha=0.234375 w/ rpp=0.23437500000000044
# no attack for alpha=0.2265625
# no attack for alpha=0.23046875
#    attack for alpha=0.232421875 w/ rpp=0.23242187500000003
#    attack for alpha=0.2314453125 w/ rpp=0.23144531250000092
# no attack for alpha=0.23095703125
#    attack for alpha=0.231201171875 w/ rpp=0.23120117187500094
# gamma = 0.25, distance = 1
#    attack for alpha=0.5 w/ rpp=0.5211132725296131
# no attack for alpha=0.25
# no attack for alpha=0.375
#    attack for alpha=0.4375 w/ rpp=0.43970931538809094
#    attack for alpha=0.40625 w/ rpp=0.4062500000000007
#    attack for alpha=0.390625 w/ rpp=0.3906250000000036
#    attack for alpha=0.3828125 w/ rpp=0.3828125000000013
# no attack for alpha=0.37890625
#    attack for alpha=0.380859375 w/ rpp=0.3808593750000005
#    attack for alpha=0.3798828125 w/ rpp=0.379882812500001
# no attack for alpha=0.37939453125
# no attack for alpha=0.379638671875
# gamma = 0.25, distance = 2
#    attack for alpha=0.5 w/ rpp=0.5700635540998571
# no attack for alpha=0.25
#    attack for alpha=0.375 w/ rpp=0.3854193597045398
# no attack for alpha=0.3125
#    attack for alpha=0.34375 w/ rpp=0.34375000000000144
#    attack for alpha=0.328125 w/ rpp=0.32812500000000655
#    attack for alpha=0.3203125 w/ rpp=0.32031250000000505
#    attack for alpha=0.31640625 w/ rpp=0.31640625000000006
#    attack for alpha=0.314453125 w/ rpp=0.3144531250000016
# no attack for alpha=0.3134765625
# no attack for alpha=0.31396484375
#    attack for alpha=0.314208984375 w/ rpp=0.3142089843750039
# gamma = 0.25, distance = 3
#    attack for alpha=0.5 w/ rpp=0.6048052303538646
# no attack for alpha=0.25
#    attack for alpha=0.375 w/ rpp=0.40080783445138085
# no attack for alpha=0.3125
#    attack for alpha=0.34375 w/ rpp=0.3509358788169138
#    attack for alpha=0.328125 w/ rpp=0.32812500000000655
#    attack for alpha=0.3203125 w/ rpp=0.32031250000000505
#    attack for alpha=0.31640625 w/ rpp=0.31640625000000006
#    attack for alpha=0.314453125 w/ rpp=0.3144531250000016
# no attack for alpha=0.3134765625
# no attack for alpha=0.31396484375
#    attack for alpha=0.314208984375 w/ rpp=0.3142089843750039
# gamma = 0.25, distance = 4
#    attack for alpha=0.5 w/ rpp=0.6380391540108108
# no attack for alpha=0.25
#    attack for alpha=0.375 w/ rpp=0.41150140798161366
# no attack for alpha=0.3125
#    attack for alpha=0.34375 w/ rpp=0.3592262447965708
#    attack for alpha=0.328125 w/ rpp=0.33375143312155847
#    attack for alpha=0.3203125 w/ rpp=0.321214077625618
#    attack for alpha=0.31640625 w/ rpp=0.31640625000000006
#    attack for alpha=0.314453125 w/ rpp=0.3144531250000016
# no attack for alpha=0.3134765625
# no attack for alpha=0.31396484375
#    attack for alpha=0.314208984375 w/ rpp=0.31420898437500394
# gamma = 0.25, distance = 5
#    attack for alpha=0.5 w/ rpp=0.6737768602589866
# no attack for alpha=0.25
#    attack for alpha=0.375 w/ rpp=0.4198228812306774
#    attack for alpha=0.3125 w/ rpp=0.3125161912379279
# no attack for alpha=0.28125
# no attack for alpha=0.296875
# no attack for alpha=0.3046875
#    attack for alpha=0.30859375 w/ rpp=0.30859375000000183
#    attack for alpha=0.306640625 w/ rpp=0.30664062500000155
# no attack for alpha=0.3056640625
#    attack for alpha=0.30615234375 w/ rpp=0.30615234375000056
#    attack for alpha=0.305908203125 w/ rpp=0.3059082031250007
# gamma = 0.5, distance = 1
#    attack for alpha=0.5 w/ rpp=0.5450400831492349
#    attack for alpha=0.25 w/ rpp=0.25000000000000056
# no attack for alpha=0.125
# no attack for alpha=0.1875
#    attack for alpha=0.21875 w/ rpp=0.218750000000001
#    attack for alpha=0.203125 w/ rpp=0.20312500000000427
#    attack for alpha=0.1953125 w/ rpp=0.1953125000000021
# no attack for alpha=0.19140625
# no attack for alpha=0.193359375
#    attack for alpha=0.1943359375 w/ rpp=0.19433593750000067
#    attack for alpha=0.19384765625 w/ rpp=0.19384765625000056
# no attack for alpha=0.193603515625
# gamma = 0.5, distance = 2
#    attack for alpha=0.5 w/ rpp=0.589543199050206
#    attack for alpha=0.25 w/ rpp=0.25000000000000056
# no attack for alpha=0.125
# no attack for alpha=0.1875
#    attack for alpha=0.21875 w/ rpp=0.21875000000000105
#    attack for alpha=0.203125 w/ rpp=0.2031250000000043
#    attack for alpha=0.1953125 w/ rpp=0.1953125000000021
# no attack for alpha=0.19140625
# no attack for alpha=0.193359375
#    attack for alpha=0.1943359375 w/ rpp=0.19433593750000067
#    attack for alpha=0.19384765625 w/ rpp=0.1938476562500006
# no attack for alpha=0.193603515625
# gamma = 0.5, distance = 3
#    attack for alpha=0.5 w/ rpp=0.6413592378226436
#    attack for alpha=0.25 w/ rpp=0.25000000000000056
# no attack for alpha=0.125
# no attack for alpha=0.1875
#    attack for alpha=0.21875 w/ rpp=0.21875000000000105
#    attack for alpha=0.203125 w/ rpp=0.2031250000000043
#    attack for alpha=0.1953125 w/ rpp=0.1953125000000021
# no attack for alpha=0.19140625
# no attack for alpha=0.193359375
#    attack for alpha=0.1943359375 w/ rpp=0.19433593750000067
#    attack for alpha=0.19384765625 w/ rpp=0.1938476562500006
# no attack for alpha=0.193603515625
# gamma = 0.5, distance = 4
#    attack for alpha=0.5 w/ rpp=0.6799300438899242
#    attack for alpha=0.25 w/ rpp=0.25000000000000056
# no attack for alpha=0.125
# no attack for alpha=0.1875
#    attack for alpha=0.21875 w/ rpp=0.21875000000000103
#    attack for alpha=0.203125 w/ rpp=0.20312500000000433
#    attack for alpha=0.1953125 w/ rpp=0.1953125000000021
# no attack for alpha=0.19140625
# no attack for alpha=0.193359375
#    attack for alpha=0.1943359375 w/ rpp=0.1943359375000007
#    attack for alpha=0.19384765625 w/ rpp=0.19384765625000058
# no attack for alpha=0.193603515625
# gamma = 0.5, distance = 5
#    attack for alpha=0.5 w/ rpp=0.7209016768889626
#    attack for alpha=0.25 w/ rpp=0.25000000000000056
# no attack for alpha=0.125
# no attack for alpha=0.1875
#    attack for alpha=0.21875 w/ rpp=0.21875000000000103
#    attack for alpha=0.203125 w/ rpp=0.20312500000000427
#    attack for alpha=0.1953125 w/ rpp=0.1953125000000021
# no attack for alpha=0.19140625
# no attack for alpha=0.193359375
#    attack for alpha=0.1943359375 w/ rpp=0.1943359375000007
#    attack for alpha=0.19384765625 w/ rpp=0.19384765625000058
# no attack for alpha=0.193603515625
# gamma = 0.75, distance = 1
#    attack for alpha=0.5 w/ rpp=0.5712239417031103
#    attack for alpha=0.25 w/ rpp=0.26046093590977787
#    attack for alpha=0.125 w/ rpp=0.125000000000002
#    attack for alpha=0.0625 w/ rpp=0.06250000000000033
# no attack for alpha=0.03125
# no attack for alpha=0.046875
# no attack for alpha=0.0546875
#    attack for alpha=0.05859375 w/ rpp=0.058593750000000354
#    attack for alpha=0.056640625 w/ rpp=0.05664062500000035
# no attack for alpha=0.0556640625
# no attack for alpha=0.05615234375
#    attack for alpha=0.056396484375 w/ rpp=0.05639648437500028
# gamma = 0.75, distance = 2
#    attack for alpha=0.5 w/ rpp=0.6210439575186558
#    attack for alpha=0.25 w/ rpp=0.27073660349258943
#    attack for alpha=0.125 w/ rpp=0.12500000000000197
#    attack for alpha=0.0625 w/ rpp=0.0625000000000003
# no attack for alpha=0.03125
# no attack for alpha=0.046875
# no attack for alpha=0.0546875
#    attack for alpha=0.05859375 w/ rpp=0.058593750000000354
#    attack for alpha=0.056640625 w/ rpp=0.05664062500000035
# no attack for alpha=0.0556640625
# no attack for alpha=0.05615234375
#    attack for alpha=0.056396484375 w/ rpp=0.056396484375000305
# gamma = 0.75, distance = 3
#    attack for alpha=0.5 w/ rpp=0.6923706800210291
#    attack for alpha=0.25 w/ rpp=0.2770279321356175
#    attack for alpha=0.125 w/ rpp=0.12500000000000197
#    attack for alpha=0.0625 w/ rpp=0.0625000000000003
# no attack for alpha=0.03125
# no attack for alpha=0.046875
# no attack for alpha=0.0546875
#    attack for alpha=0.05859375 w/ rpp=0.058593750000000354
#    attack for alpha=0.056640625 w/ rpp=0.05664062500000035
# no attack for alpha=0.0556640625
# no attack for alpha=0.05615234375
#    attack for alpha=0.056396484375 w/ rpp=0.056396484375000305
# gamma = 0.75, distance = 4
#    attack for alpha=0.5 w/ rpp=0.7337778537630768
#    attack for alpha=0.25 w/ rpp=0.2823059332873847
#    attack for alpha=0.125 w/ rpp=0.12500000000000194
#    attack for alpha=0.0625 w/ rpp=0.0625000000000003
# no attack for alpha=0.03125
# no attack for alpha=0.046875
# no attack for alpha=0.0546875
#    attack for alpha=0.05859375 w/ rpp=0.05859375000000036
#    attack for alpha=0.056640625 w/ rpp=0.05664062500000036
# no attack for alpha=0.0556640625
# no attack for alpha=0.05615234375
#    attack for alpha=0.056396484375 w/ rpp=0.056396484375000305
# gamma = 0.75, distance = 5
#    attack for alpha=0.5 w/ rpp=0.7659477190147214
#    attack for alpha=0.25 w/ rpp=0.28428256872494084
#    attack for alpha=0.125 w/ rpp=0.12500000000000194
#    attack for alpha=0.0625 w/ rpp=0.0625000000000003
# no attack for alpha=0.03125
# no attack for alpha=0.046875
# no attack for alpha=0.0546875
#    attack for alpha=0.05859375 w/ rpp=0.05859375000000036
#    attack for alpha=0.056640625 w/ rpp=0.05664062500000036
# no attack for alpha=0.0556640625
# no attack for alpha=0.05615234375
#    attack for alpha=0.056396484375 w/ rpp=0.056396484375000305
# gamma = 1, distance = 1
#    attack for alpha=0.5 w/ rpp=0.5999999867377265
#    attack for alpha=0.25 w/ rpp=0.2941176329564463
#    attack for alpha=0.125 w/ rpp=0.13846152897312103
#    attack for alpha=0.0625 w/ rpp=0.06614785444960722
#    attack for alpha=0.03125 w/ rpp=0.03219511901783638
#    attack for alpha=0.015625 w/ rpp=0.015865265768462745
#    attack for alpha=0.0078125 w/ rpp=0.00787305385376942
#    attack for alpha=0.00390625 w/ rpp=0.003921448567414789
#    attack for alpha=0.001953125 w/ rpp=0.0019569320369262604
#    attack for alpha=0.0009765625 w/ rpp=0.000977515144321229
#    attack for alpha=0.00048828125 w/ rpp=0.0004885195027882067
#    attack for alpha=0.000244140625 w/ rpp=0.0002442001896575776
# gamma = 1, distance = 2
#    attack for alpha=0.5 w/ rpp=0.6655628493883045
#    attack for alpha=0.25 w/ rpp=0.3075152910103688
#    attack for alpha=0.125 w/ rpp=0.1403293381007932
#    attack for alpha=0.0625 w/ rpp=0.06638744839140584
#    attack for alpha=0.03125 w/ rpp=0.032225258646744234
#    attack for alpha=0.015625 w/ rpp=0.015869038297416756
#    attack for alpha=0.0078125 w/ rpp=0.007873525569365138
#    attack for alpha=0.00390625 w/ rpp=0.003921507420060585
#    attack for alpha=0.001953125 w/ rpp=0.001956939305773266
#    attack for alpha=0.0009765625 w/ rpp=0.0009775160342007957
#    attack for alpha=0.00048828125 w/ rpp=0.0004885196101010858
#    attack for alpha=0.000244140625 w/ rpp=0.00024420020255790315
# gamma = 1, distance = 3
#    attack for alpha=0.5 w/ rpp=0.7469286036759579
#    attack for alpha=0.25 w/ rpp=0.3246462359120124
#    attack for alpha=0.125 w/ rpp=0.14246899890647746
#    attack for alpha=0.0625 w/ rpp=0.06664511133124508
#    attack for alpha=0.03125 w/ rpp=0.03225666516383789
#    attack for alpha=0.015625 w/ rpp=0.015872909652011838
#    attack for alpha=0.0078125 w/ rpp=0.007874005461806513
#    attack for alpha=0.00390625 w/ rpp=0.003921567022657899
#    attack for alpha=0.001953125 w/ rpp=0.0019569467402182775
#    attack for alpha=0.0009765625 w/ rpp=0.000977516961749056
#    attack for alpha=0.00048828125 w/ rpp=0.000488519726152712
#    attack for alpha=0.000244140625 w/ rpp=0.00024420021720733575
# gamma = 1, distance = 4
#    attack for alpha=0.5 w/ rpp=0.7945620010846104
#    attack for alpha=0.25 w/ rpp=0.33011999358174166
#    attack for alpha=0.125 w/ rpp=0.14277280438377402
#    attack for alpha=0.0625 w/ rpp=0.0666622595678184
#    attack for alpha=0.03125 w/ rpp=0.03225767759604142
#    attack for alpha=0.015625 w/ rpp=0.015872971096603627
#    attack for alpha=0.0078125 w/ rpp=0.007874009251432067
#    attack for alpha=0.00390625 w/ rpp=0.003921567260999986
#    attack for alpha=0.001953125 w/ rpp=0.001956946754820523
#    attack for alpha=0.0009765625 w/ rpp=0.0009775169630563242
#    attack for alpha=0.00048828125 w/ rpp=0.000488519726310292
#    attack for alpha=0.000244140625 w/ rpp=0.00024420021724134354
# gamma = 1, distance = 5
#    attack for alpha=0.5 w/ rpp=0.825347648953942
#    attack for alpha=0.25 w/ rpp=0.33190780910222084
#    attack for alpha=0.125 w/ rpp=0.14281604585594396
#    attack for alpha=0.0625 w/ rpp=0.06666340121401186
#    attack for alpha=0.03125 w/ rpp=0.032257710264753436
#    attack for alpha=0.015625 w/ rpp=0.015872972087077684
#    attack for alpha=0.0078125 w/ rpp=0.007874009288945593
#    attack for alpha=0.00390625 w/ rpp=0.0039215672657985454
#    attack for alpha=0.001953125 w/ rpp=0.0019569467548490945
#    attack for alpha=0.0009765625 w/ rpp=0.0009775169640237808
#    attack for alpha=0.00048828125 w/ rpp=0.0004885197267998626
#    attack for alpha=0.000244140625 w/ rpp=0.00024420021749120606

# %% [raw]
# from lib.models.generic_v0.ethereum import EthereumWhitepaper, EthereumByzantium
# for gamma in [0, 0.5, 1]:
#     for distance in range(1, 3):
#         print(f"gamma = {gamma}, distance = {distance}")
#         localize_be(gamma, distance, precision, protocol=EthereumByzantium(horizon=3))

# %% [raw]
# for (gamma, distance, alpha), res in evaluations.items():
#     if (gamma, distance) not in break_even:
#         break_even[(gamma, distance)] = 1.0
#
#     if not res["honest"]:
#         break_even[(gamma, distance)] = min(break_even[(gamma, distance)], alpha)

# %%
import pandas as pd
import seaborn as sns

df = pd.DataFrame(
    [(distance, gamma, be) for (gamma, distance), be in break_even.items()],
    columns=["distance", "gamma", "alpha"],
)
sns.relplot(data=df, x="gamma", y="alpha", hue="distance")
